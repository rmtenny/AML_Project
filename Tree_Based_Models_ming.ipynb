# %% [markdown]
# # Constructing Tree-Based Models

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")
import time

# %%
import gc
gc.collect()
# Out:
# 0

# %%
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in d:\anaconda\lib\site-packages (1.1.1)

# %%
import joblib

# %%
# train_dataset = pd.read_csv(r"train_dataset.csv", index_col = 0)
# val_dataset = pd.read_csv(r"val_dataset.csv", index_col = 0)
# test_dataset = pd.read_csv(r"test_dataset.csv", index_col = 0)

# features = pd.read_csv(r"features.csv", index_col = 0)

# %%
train_dataset_top = pd.read_csv(r"train_dataset_top.csv", index_col = 0)
val_dataset_top = pd.read_csv(r"val_dataset_top.csv", index_col = 0)
test_dataset_top = pd.read_csv(r"test_dataset_top.csv", index_col = 0)

features_top = pd.read_csv(r"features_top.csv", index_col = 0)

# %%
train_dataset_top
# Out:
#         permno    DATE     mvel1      beta    betasq     chmom    dolvol  \
# 165      14593  201506  1.000000 -0.392488 -0.843512  0.319507  0.968018
# 167      14593  201503  0.993421 -0.373529 -0.832350  0.346878  0.971090
# 176      14593  201504  0.930708 -0.359465 -0.823821  0.354844  0.965641
# 178      14593  201505  0.921025 -0.351181 -0.818698  0.343828  0.974312
# 181      14593  201507  0.906199 -0.377502 -0.834720  0.362267  0.956196
# ...        ...     ...       ...       ...       ...       ...       ...
# 143995   71810  201007 -0.999962 -0.417357 -0.857571  0.344090  0.388166
# 143996   93223  201009 -0.999964 -0.354021 -0.820463  0.342438  0.546012
# 143997   81678  201009 -0.999987 -0.217733 -0.726060  0.373264  0.491475
# 143998   81912  201009 -0.999996 -0.569619 -0.929223  0.362420  0.459664
# 143999   85424  201009 -1.000000 -0.156725 -0.677363  0.295842  0.619961
#
#          idiovol    indmom     mom1m  ...  invest*dfy  invest*svar  \
# 165    -0.718208 -0.604590 -0.119343  ...   -0.365988    -0.374302
# 167    -0.711564 -0.659332 -0.020089  ...   -0.379144    -0.372207
# 176    -0.717428 -0.627439 -0.256641  ...   -0.364658    -0.377033
# 178    -0.720239 -0.596675 -0.189967  ...   -0.367983    -0.375246
# 181    -0.719959 -0.620920 -0.267217  ...   -0.358673    -0.373687
# ...          ...       ...       ...  ...         ...          ...
# 143995 -0.725931 -0.489277 -0.164908  ...   -0.399507    -0.373848
# 143996 -0.610931 -0.529142 -0.184627  ...   -0.403334    -0.375843
# 143997 -0.640793 -0.454958 -0.384268  ...   -0.440531    -0.382456
# 143998 -0.714866 -0.510021 -0.415721  ...   -0.629789    -0.416103
# 143999 -0.557295 -0.454958 -0.180100  ...   -0.248191    -0.348261
#
#         absacc*dp_sp  absacc*ep_sp  absacc*bm_sp  absacc*ntis  absacc*tbl  \
# 165        -0.754788     -0.816891     -0.810511    -0.285030   -0.969760
# 167        -0.774483     -0.819861     -0.822897    -0.271672   -0.957228
# 176        -0.761046     -0.813335     -0.812858    -0.275138   -0.969760
# 178        -0.761733     -0.818006     -0.814626    -0.281153   -0.969760
# 181        -0.758060     -0.823116     -0.811265    -0.284888   -0.954640
# ...              ...           ...           ...          ...         ...
# 143995     -0.851645     -0.848859     -0.852628    -0.175964   -0.852672
# 143996     -0.853107     -0.844911     -0.854731    -0.220364   -0.859660
# 143997     -0.696140     -0.679185     -0.699499    -0.207139   -0.709696
# 143998     -0.979467     -0.978321     -0.979694    -0.231010   -0.980383
# 143999     -0.892347     -0.886340     -0.893537    -0.223670   -0.897149
#
#         absacc*tms  absacc*dfy  absacc*svar
# 165      -0.831976   -0.819573    -0.974298
# 167      -0.872915   -0.837108    -0.960373
# 176      -0.853350   -0.815734    -0.985970
# 178      -0.845632   -0.825331    -0.978333
# 181      -0.845632   -0.798459    -0.971669
# ...            ...         ...          ...
# 143995   -0.869472   -0.849209    -0.950183
# 143996   -0.880233   -0.865789    -0.964673
# 143997   -0.752251   -0.722374    -0.926923
# 143998   -0.983258   -0.981239    -0.995062
# 143999   -0.912226   -0.901641    -0.974110
#
# [72000 rows x 914 columns]

# %%
val_dataset_top
# Out:
#         permno    DATE     mvel1      beta    betasq     chmom    dolvol  \
# 109      14593  201712  1.000000 -0.427168 -0.866469 -0.188808  0.999985
# 116      14593  201711  0.967175 -0.422871 -0.864160 -0.109102  0.974043
# 129      14593  201709  0.919836 -0.421542 -0.863441 -0.111741  0.964810
# 147      14593  201706  0.804640 -0.432036 -0.869060  0.063186  0.954546
# 149      14593  201710  0.790043 -0.430363 -0.868173 -0.161052  0.969809
# ...        ...     ...       ...       ...       ...       ...       ...
# 137476   14539  201603 -0.999930 -0.361609 -0.829087 -0.116573  0.637090
# 137485   58975  201602 -0.999932 -0.070517 -0.607461 -0.026761  0.562158
# 137511   31500  201602 -0.999938 -0.100652 -0.634620 -0.163056  0.525813
# 137565   75041  201603 -0.999956 -0.459713 -0.883315 -0.025804  0.386708
# 137746   91321  201603 -1.000000  0.753481  0.512384  0.104888  0.506756
#
#          idiovol    indmom     mom1m  ...  invest*dfy  invest*svar  \
# 109    -0.694169 -0.239114 -0.117523  ...   -0.405542    -0.438850
# 116    -0.694448 -0.177485  0.020920  ...   -0.406073    -0.436860
# 129    -0.689649 -0.259303  0.039203  ...   -0.407665    -0.438615
# 147    -0.693470 -0.189259 -0.031598  ...   -0.406603    -0.435210
# 149    -0.696905 -0.305205 -0.263456  ...   -0.405011    -0.439314
# ...          ...       ...       ...  ...         ...          ...
# 137476 -0.875453 -0.565556 -0.167531  ...   -0.409703    -0.432228
# 137485 -0.663091 -0.872612 -0.331486  ...   -0.319783    -0.364774
# 137511 -0.717380 -0.520198 -0.350071  ...   -0.440848    -0.441711
# 137565 -0.749738 -0.479529  0.006529  ...   -0.365305    -0.417671
# 137746 -0.341644 -0.826768  0.790844  ...   -0.314977    -0.401169
#
#         absacc*dp_sp  absacc*ep_sp  absacc*bm_sp  absacc*ntis  absacc*tbl  \
# 109        -0.832627     -0.812921     -0.856685     0.880388   -0.788533
# 116        -0.827774     -0.808139     -0.854047     0.926637   -0.802951
# 129        -0.825134     -0.806526     -0.841883     0.933300   -0.834992
# 147        -0.821811     -0.804613     -0.834066     0.941129   -0.843002
# 149        -0.828031     -0.809076     -0.848458     0.925520   -0.828584
# ...              ...           ...           ...          ...         ...
# 137476     -0.883076     -0.885341     -0.880158     0.914354   -0.972115
# 137485     -0.722062     -0.726339     -0.729357     0.800130   -0.933284
# 137511     -0.697071     -0.701732     -0.705021     0.782158   -0.927285
# 137565     -0.659705     -0.666299     -0.651212     0.750736   -0.918845
# 137746     -0.844611     -0.847622     -0.840733     0.886178   -0.962942
#
#         absacc*tms  absacc*dfy  absacc*svar
# 109      -0.895394   -0.878329    -0.985898
# 116      -0.882533   -0.880043    -0.979472
# 129      -0.866241   -0.885184    -0.985139
# 147      -0.862812   -0.881756    -0.974145
# 149      -0.867956   -0.876615    -0.987397
# ...            ...         ...          ...
# 137476   -0.902735   -0.865259    -0.955821
# 137485   -0.785755   -0.682305    -0.798103
# 137511   -0.766491   -0.653740    -0.779950
# 137565   -0.716920   -0.607851    -0.871421
# 137746   -0.870737   -0.820933    -0.941287
#
# [24000 rows x 914 columns]

# %%
test_dataset_top
# Out:
#         permno    DATE     mvel1      beta    betasq     chmom    dolvol  \
# 0        14593  202112  1.000000 -0.517544 -0.917058  0.083234  0.935369
# 1        14593  202109  0.850689 -0.513482 -0.915312  0.090737  0.932078
# 2        10107  202111  0.835936 -0.613520 -0.953011  0.035643  0.942327
# 3        10107  202112  0.830225 -0.612965 -0.952832  0.055599  0.935369
# 4        14593  202111  0.812219 -0.513624 -0.915374  0.004744  0.942327
# ...        ...     ...       ...       ...       ...       ...       ...
# 135687   60943  202004 -0.999988 -0.216641 -0.738566 -0.052503  0.530406
# 135744   18770  202004 -0.999993 -0.317152 -0.809281 -0.034219  0.335590
# 135768   18769  202004 -0.999994 -0.317152 -0.809281 -0.034219  0.453554
# 135818   90550  202004 -1.000000 -0.304787 -0.801182 -0.022320  0.479126
# 135819   13612  202004 -1.000000 -0.921091 -0.999868  0.017111  0.423602
#
#          idiovol    indmom     mom1m  ...  invest*dfy  invest*svar  \
# 0      -0.766950 -0.369577 -0.175821  ...   -0.337816    -0.407181
# 1      -0.755616 -0.124235 -0.242029  ...   -0.335102    -0.408639
# 2      -0.801956 -0.176537 -0.100240  ...   -0.329061    -0.408331
# 3      -0.804418 -0.335381 -0.288292  ...   -0.329728    -0.406433
# 4      -0.764305 -0.243932 -0.224848  ...   -0.337273    -0.408725
# ...          ...       ...       ...  ...         ...          ...
# 135687 -0.803309 -0.627077 -0.622984  ...   -0.282093    -0.392161
# 135744 -0.802412 -0.585561 -0.382677  ...   -0.333369    -0.402463
# 135768 -0.802412 -0.585561 -0.299046  ...   -0.333369    -0.402463
# 135818 -0.829515 -0.580531 -0.472237  ...   -0.311505    -0.398070
# 135819 -0.987052 -0.585561 -0.296143  ...   -0.333369    -0.402463
#
#         absacc*dp_sp  absacc*ep_sp  absacc*bm_sp  absacc*ntis  absacc*tbl  \
# 0          -0.870484     -0.809642     -0.864945     0.345191   -0.994172
# 1          -0.859405     -0.813324     -0.854991     0.361192   -0.996115
# 2          -0.893346     -0.848228     -0.886988     0.341805   -0.996143
# 3          -0.897154     -0.848841     -0.892756     0.328896   -0.995372
# 4          -0.865688     -0.808870     -0.857681     0.361447   -0.995143
# ...              ...           ...           ...          ...         ...
# 135687     -0.884515     -0.903855     -0.884515     0.230580   -0.992493
# 135744     -0.880806     -0.900766     -0.880806     0.229440   -0.992252
# 135768     -0.880806     -0.900766     -0.880806     0.229440   -0.992252
# 135818     -0.921178     -0.934378     -0.921178     0.241843   -0.994876
# 135819     -0.880806     -0.900766     -0.880806     0.229440   -0.992252
#
#         absacc*tms  absacc*dfy  absacc*svar
# 0        -0.563798   -0.920009    -0.988168
# 1        -0.574823   -0.913856    -0.993453
# 2        -0.592870   -0.935504    -0.995051
# 3        -0.603814   -0.936481    -0.990605
# 4        -0.550015   -0.918778    -0.993767
# ...            ...         ...          ...
# 135687   -0.718565   -0.884515    -0.962895
# 135744   -0.717294   -0.880806    -0.961703
# 135768   -0.717294   -0.880806    -0.961703
# 135818   -0.731124   -0.921178    -0.974674
# 135819   -0.717294   -0.880806    -0.961703
#
# [48000 rows x 914 columns]

# %%
features_top = features_top['0'].to_list()

# %%
features_top
# Out:
# ['sin*ep_sp',
#  'beta*ep_sp',
#  'dy*dp_sp',
#  'ear*bm_sp',
#  'chpmia*ntis',
#  'chtx*tbl',
#  'cashdebt*ntis',
#  'chatoia*svar',
#  'ep*bm_sp',
#  'sic_67',
#  'stdacc*ep_sp',
#  'invest*dp_sp',
#  'roavol*tbl',
#  'realestate*ep_sp',
#  'lgr',
#  'roic*svar',
#  'retvol*tms',
#  'sgr',
#  'roaq*ep_sp',
#  'quick*bm_sp',
#  'chpmia',
#  'age*bm_sp',
#  'lgr*tbl',
#  'rsup*dfy',
#  'chempia*tbl',
#  'cinvest*tms',
#  'zerotrade',
#  'secured*dfy',
#  'pchsale_pchinvt*dfy',
#  'acc*bm_sp',
#  'ear*dfy',
#  'operprof*svar',
#  'lgr*dfy',
#  'retvol*ntis',
#  'ms*svar',
#  'pctacc*svar',
#  'sic_25',
#  'cfp*ep_sp',
#  'pchsale_pchinvt*bm_sp',
#  'absacc*tbl',
#  'stdcf*dfy',
#  'pchsale_pchrect*tbl',
#  'herf*dfy',
#  'pchgm_pchsale',
#  'baspread*tbl',
#  'herf*dp_sp',
#  'age*ntis',
#  'pchcurrat*ep_sp',
#  'pchcurrat',
#  'maxret',
#  'chempia*dp_sp',
#  'rd*tms',
#  'tb*ep_sp',
#  'sin*ntis',
#  'ms*ntis',
#  'pchcapx_ia*ntis',
#  'betasq',
#  'depr*dp_sp',
#  'egr*tms',
#  'pchsale_pchinvt',
#  'divi',
#  'absacc*ep_sp',
#  'chpmia*ep_sp',
#  'ear*ep_sp',
#  'rd_mve*dp_sp',
#  'baspread*ep_sp',
#  'chtx*dfy',
#  'orgcap*dfy',
#  'invest*tbl',
#  'pchquick*ep_sp',
#  'pchdepr*tbl',
#  'retvol*dfy',
#  'bm*dfy',
#  'tb*dfy',
#  'dolvol*ntis',
#  'baspread',
#  'beta*dfy',
#  'pchdepr*tms',
#  'mve_ia*tms',
#  'roavol*ntis',
#  'salerec*ep_sp',
#  'hire*svar',
#  'ms*ep_sp',
#  'sp*svar',
#  'rd*svar',
#  'ill*dfy',
#  'cfp_ia',
#  'sic_39',
#  'betasq*ntis',
#  'depr*dfy',
#  'quick*svar',
#  'pchsale_pchrect',
#  'mom1m*bm_sp',
#  'chempia*ntis',
#  'chmom*bm_sp',
#  'chinv*ntis',
#  'cashpr*tms',
#  'absacc',
#  'pchsale_pchxsga*ep_sp',
#  'tang*tbl',
#  'cash*ntis',
#  'ill*dp_sp',
#  'chempia*dfy',
#  'pchsale_pchrect*bm_sp',
#  'pchsaleinv*dfy',
#  'sic_42',
#  'sic_73',
#  'realestate*dp_sp',
#  'chmom*dp_sp',
#  'pchsale_pchrect*tms',
#  'sic_79',
#  'hire',
#  'pchsaleinv*ep_sp',
#  'realestate*bm_sp',
#  'pchgm_pchsale*ep_sp',
#  'chcsho*bm_sp',
#  'retvol*tbl',
#  'operprof*bm_sp',
#  'roic*bm_sp',
#  'lgr*bm_sp',
#  'stdacc*ntis',
#  'depr*svar',
#  'orgcap*dp_sp',
#  'turn',
#  'sic_24',
#  'sic_53',
#  'chinv*tbl',
#  'currat*tbl',
#  'gma*dfy',
#  'sp*tbl',
#  'pchdepr*dp_sp',
#  'tang*bm_sp',
#  'agr*ntis',
#  'pricedelay*dp_sp',
#  'tb*bm_sp',
#  'sic_13',
#  'divo*ep_sp',
#  'rd*tbl',
#  'mom6m*ntis',
#  'turn*dp_sp',
#  'idiovol*bm_sp',
#  'dolvol*bm_sp',
#  'mom12m*tbl',
#  'mvel1*tbl',
#  'pchquick*tbl',
#  'indmom*bm_sp',
#  'rsup*tbl',
#  'roaq*bm_sp',
#  'ear*ntis',
#  'chatoia*dfy',
#  'cfp*tbl',
#  'pchcapx_ia*ep_sp',
#  'cfp_ia*ntis',
#  'mom6m*tms',
#  'divo*bm_sp',
#  'sic_80',
#  'cashpr*ntis',
#  'rsup*svar',
#  'pchgm_pchsale*ntis',
#  'mom36m*dp_sp',
#  'zerotrade*bm_sp',
#  'agr*bm_sp',
#  'idiovol*dfy',
#  'chmom*dfy',
#  'ps*ntis',
#  'divi*bm_sp',
#  'pchdepr',
#  'sic_70',
#  'std_turn*ep_sp',
#  'chpmia*bm_sp',
#  'pchsale_pchrect*ep_sp',
#  'hire*tbl',
#  'agr*svar',
#  'beta*tbl',
#  'securedind*tms',
#  'pchcurrat*bm_sp',
#  'hire*dfy',
#  'chinv*svar',
#  'beta*ntis',
#  'gma*ep_sp',
#  'ms*dp_sp',
#  'ill*tms',
#  'stdacc*tbl',
#  'convind*ntis',
#  'divo',
#  'sic_72',
#  'mve_ia*tbl',
#  'mom36m*tms',
#  'ill*ep_sp',
#  'grcapx',
#  'dolvol*dfy',
#  'sgr*tbl',
#  'chempia*ep_sp',
#  'age*dfy',
#  'currat*bm_sp',
#  'sic_40',
#  'pchcapx_ia*tms',
#  'divo*tms',
#  'chcsho*svar',
#  'sgr*bm_sp',
#  'mom36m*tbl',
#  'pchdepr*ntis',
#  'roavol*tms',
#  'quick*dfy',
#  'sic_15',
#  'sgr*tms',
#  'lev*svar',
#  'sic_50',
#  'zerotrade*ntis',
#  'sic_58',
#  'depr*tbl',
#  'salecash*bm_sp',
#  'sic_49',
#  'saleinv*dfy',
#  'sgr*dfy',
#  'stdcf*dp_sp',
#  'cashpr*dfy',
#  'sic_26',
#  'stdcf*ntis',
#  'divi*ep_sp',
#  'roavol*dp_sp',
#  'aeavol*tms',
#  'pchdepr*dfy',
#  'sin*bm_sp',
#  'grcapx*ep_sp',
#  'ms*tbl',
#  'mom1m*dfy',
#  'bm*dp_sp',
#  'salecash*svar',
#  'retvol*bm_sp',
#  'stdacc*bm_sp',
#  'salecash*ep_sp',
#  'turn*bm_sp',
#  'baspread*svar',
#  'mve_ia*dfy',
#  'tb*dp_sp',
#  'nincr*tms',
#  'chatoia*bm_sp',
#  'gma*tms',
#  'currat*ep_sp',
#  'grcapx*ntis',
#  'pricedelay*ep_sp',
#  'convind*dfy',
#  'invest*tms',
#  'aeavol*bm_sp',
#  'sic_17',
#  'cash*dp_sp',
#  'betasq*ep_sp',
#  'bm*svar',
#  'gma*dp_sp',
#  'pchgm_pchsale*tms',
#  'sic_56',
#  'secured*dp_sp',
#  'chinv*dfy',
#  'grcapx*dp_sp',
#  'cfp',
#  'pchsaleinv*svar',
#  'idiovol*dp_sp',
#  'std_turn*dp_sp',
#  'saleinv*tms',
#  'chcsho*ntis',
#  'pchsaleinv*tbl',
#  'sp*ntis',
#  'ps*dp_sp',
#  'sic_57',
#  'roaq',
#  'betasq*dfy',
#  'chpmia*tms',
#  'convind*ep_sp',
#  'grltnoa*ntis',
#  'beta*bm_sp',
#  'quick*ntis',
#  'roic',
#  'chatoia*tms',
#  'dy',
#  'orgcap',
#  'ps*ep_sp',
#  'baspread*ntis',
#  'std_dolvol*ntis',
#  'maxret*tbl',
#  'salerec*tms',
#  'bm*tms',
#  'acc*tms',
#  'operprof*ntis',
#  'dy*tms',
#  'divo*dp_sp',
#  'sgr*dp_sp',
#  'chempia',
#  'tang*dfy',
#  'rd_mve*bm_sp',
#  'cfp*dfy',
#  'roaq*tms',
#  'orgcap*ntis',
#  'turn*ntis',
#  'chpmia*dfy',
#  'mom1m*svar',
#  'maxret*tms',
#  'chtx*tms',
#  'bm*ntis',
#  'maxret*bm_sp',
#  'sp*bm_sp',
#  'pchdepr*bm_sp',
#  'realestate*tbl',
#  'aeavol*ep_sp',
#  'stdacc*svar',
#  'sic_87',
#  'ep*ep_sp',
#  'dy*dfy',
#  'indmom*ntis',
#  'grltnoa*dp_sp',
#  'ms*dfy',
#  'egr*svar',
#  'herf*ntis',
#  'aeavol*tbl',
#  'rsup*tms',
#  'saleinv*svar',
#  'betasq*dp_sp',
#  'acc*dp_sp',
#  'aeavol*dp_sp',
#  'cashpr*bm_sp',
#  'nincr*svar',
#  'bm_ia*ntis',
#  'mom6m',
#  'ear*dp_sp',
#  'rsup*ep_sp',
#  'salecash*ntis',
#  'cashdebt*ep_sp',
#  'saleinv*bm_sp',
#  'mom1m*tms',
#  'ps*svar',
#  'mve_ia*ep_sp',
#  'sp*dfy',
#  'saleinv',
#  'lev*dp_sp',
#  'grcapx*bm_sp',
#  'chtx*svar',
#  'operprof*dfy',
#  'chatoia*tbl',
#  'lev*ntis',
#  'chmom*tms',
#  'realestate',
#  'chpmia*svar',
#  'dolvol*tbl',
#  'rd_sale*svar',
#  'hire*dp_sp',
#  'chatoia*ep_sp',
#  'pchdepr*svar',
#  'sic_62',
#  'lgr*dp_sp',
#  'chpmia*tbl',
#  'roic*ntis',
#  'stdcf',
#  'sic_12',
#  'sin*dp_sp',
#  'agr',
#  'baspread*tms',
#  'stdcf*svar',
#  'pctacc',
#  'roeq*dfy',
#  'aeavol*svar',
#  'pchcapx_ia*dfy',
#  'sic_47',
#  'secured*bm_sp',
#  'lev*tbl',
#  'pricedelay*dfy',
#  'cfp_ia*ep_sp',
#  'chmom',
#  'age*tms',
#  'lev*dfy',
#  'egr*ep_sp',
#  'lgr*ntis',
#  'realestate*dfy',
#  'roic*tbl',
#  'rd_sale*tbl',
#  'chempia*bm_sp',
#  'pchcapx_ia*svar',
#  'divo*dfy',
#  'roaq*svar',
#  'cash*ep_sp',
#  'mom12m*ntis',
#  'stdacc*tms',
#  'sic_31',
#  'aeavol*dfy',
#  'gma*ntis',
#  'bm_ia*bm_sp',
#  'nincr*bm_sp',
#  'chtx',
#  'sic_37',
#  'mom36m*dfy',
#  'zerotrade*dfy',
#  'cinvest*tbl',
#  'beta*dp_sp',
#  'dy*ep_sp',
#  'salerec*ntis',
#  'dy*tbl',
#  'dolvol',
#  'convind*dp_sp',
#  'pchsale_pchrect*dfy',
#  'agr*dfy',
#  'dolvol*ep_sp',
#  'gma',
#  'chtx*ep_sp',
#  'nincr*dp_sp',
#  'bm*ep_sp',
#  'bm_ia*tbl',
#  'divo*tbl',
#  'securedind*ntis',
#  'operprof*ep_sp',
#  'retvol',
#  'lgr*ep_sp',
#  'aeavol',
#  'mvel1*bm_sp',
#  'bm_ia*dp_sp',
#  'std_dolvol*ep_sp',
#  'idiovol*ntis',
#  'cashpr*tbl',
#  'cashpr*svar',
#  'sic_23',
#  'rd_sale*dfy',
#  'std_turn*svar',
#  'grcapx*tbl',
#  'egr*tbl',
#  'hire*tms',
#  'indmom*dfy',
#  'convind',
#  'sp*dp_sp',
#  'sic_64',
#  'pchsaleinv',
#  'ear*tms',
#  'sic_21',
#  'sic_32',
#  'chmom*ntis',
#  'dy*svar',
#  'lev*ep_sp',
#  'chcsho*dfy',
#  'acc*dfy',
#  'salerec*tbl',
#  'pchcapx_ia',
#  'pchsale_pchinvt*svar',
#  'chempia*svar',
#  'sgr*ntis',
#  'ep*tms',
#  'mom1m*tbl',
#  'sic_38',
#  'sic_61',
#  'ep*ntis',
#  'chtx*dp_sp',
#  'nincr*tbl',
#  'rd_sale*ntis',
#  'mom1m',
#  'ps*bm_sp',
#  'grltnoa',
#  'secured*ep_sp',
#  'sic_54',
#  'tb*ntis',
#  'roeq*dp_sp',
#  'pctacc*dfy',
#  'pctacc*tms',
#  'gma*tbl',
#  'bm*tbl',
#  'idiovol*tbl',
#  'securedind*bm_sp',
#  'cinvest*dfy',
#  'lev*bm_sp',
#  'invest',
#  'ep',
#  'mom36m*ntis',
#  'secured*ntis',
#  'sic_46',
#  'cfp*svar',
#  'chinv*bm_sp',
#  'chcsho*tms',
#  'ill*bm_sp',
#  'rd_mve*dfy',
#  'pchsale_pchrect*dp_sp',
#  'securedind*dfy',
#  'lev',
#  'std_turn*dfy',
#  'quick*tbl',
#  'pchcurrat*dp_sp',
#  'rd_sale',
#  'pchsaleinv*tms',
#  'hire*ntis',
#  'beta*svar',
#  'depr*bm_sp',
#  'zerotrade*dp_sp',
#  'ms',
#  'roavol*svar',
#  'pricedelay*bm_sp',
#  'operprof*dp_sp',
#  'rsup*bm_sp',
#  'pchsale_pchinvt*dp_sp',
#  'baspread*dfy',
#  'sic_83',
#  'turn*ep_sp',
#  'sic_36',
#  'securedind*svar',
#  'std_turn*tms',
#  'convind*bm_sp',
#  'pchsale_pchrect*ntis',
#  'salerec',
#  'pchquick*dfy',
#  'roeq*tms',
#  'dy*ntis',
#  'mve_ia*ntis',
#  'pricedelay',
#  'salecash*dfy',
#  'agr*dp_sp',
#  'currat*svar',
#  'roeq*svar',
#  'sin*dfy',
#  'rd*bm_sp',
#  'tang*svar',
#  'pricedelay*svar',
#  'sic_22',
#  'sp*ep_sp',
#  'turn*svar',
#  'turn*tbl',
#  'ep*svar',
#  'cinvest*ep_sp',
#  'rd',
#  'divi*svar',
#  'retvol*ep_sp',
#  'roic*ep_sp',
#  'pchsale_pchinvt*tms',
#  'agr*ep_sp',
#  'tb',
#  'bm_ia',
#  'salerec*dfy',
#  'pchgm_pchsale*bm_sp',
#  'chatoia*dp_sp',
#  'roic*dfy',
#  'roic*dp_sp',
#  'bm*bm_sp',
#  'mve_ia*bm_sp',
#  'herf*bm_sp',
#  'pchquick',
#  'mom6m*bm_sp',
#  'mom36m',
#  'ear*tbl',
#  'divi*tms',
#  'nincr*ep_sp',
#  'orgcap*ep_sp',
#  'cashdebt',
#  'acc*ntis',
#  'maxret*dfy',
#  'idiovol*svar',
#  'ill',
#  'cinvest*ntis',
#  'egr*dfy',
#  'sic_51',
#  'cashdebt*dp_sp',
#  'saleinv*ep_sp',
#  'quick',
#  'sic_45',
#  'sgr*ep_sp',
#  'mvel1*ep_sp',
#  'pctacc*bm_sp',
#  'retvol*svar',
#  'cash*tms',
#  'stdacc*dp_sp',
#  'orgcap*svar',
#  'roavol*dfy',
#  'divi*ntis',
#  'zerotrade*svar',
#  'retvol*dp_sp',
#  'mve_ia',
#  'operprof',
#  'tang*tms',
#  'secured*tms',
#  'chinv*tms',
#  'idiovol',
#  'betasq*bm_sp',
#  'aeavol*ntis',
#  'dolvol*tms',
#  'pchquick*svar',
#  'rd*dp_sp',
#  'cashdebt*tbl',
#  'mom6m*dfy',
#  'currat*ntis',
#  'cfp_ia*bm_sp',
#  'salecash',
#  'beta*tms',
#  'salecash*tms',
#  'hire*bm_sp',
#  'pchsale_pchinvt*ntis',
#  'mom6m*svar',
#  'pchsale_pchinvt*tbl',
#  'roaq*tbl',
#  'std_dolvol*svar',
#  'zerotrade*tms',
#  'bm_ia*tms',
#  'convind*tbl',
#  'age*tbl',
#  'cashdebt*svar',
#  'divi*dfy',
#  'tang*dp_sp',
#  'absacc*ntis',
#  'sic_30',
#  'cfp_ia*tbl',
#  'grltnoa*tbl',
#  'invest*ntis',
#  'egr',
#  'sic_75',
#  'salerec*svar',
#  'sic_28',
#  'mom12m*ep_sp',
#  'pchsale_pchinvt*ep_sp',
#  'ear*svar',
#  'secured*svar',
#  'depr*tms',
#  'grcapx*svar',
#  'pchcurrat*tms',
#  'mom12m*tms',
#  'bm_ia*svar',
#  'cashdebt*bm_sp',
#  'pchcurrat*ntis',
#  'grltnoa*ep_sp',
#  'tang*ntis',
#  'acc*tbl',
#  'mom12m',
#  'sic_1',
#  'tb*tms',
#  'stdcf*tbl',
#  'chatoia',
#  'cfp_ia*tms',
#  'sic_27',
#  'stdacc*dfy',
#  'maxret*svar',
#  'mvel1*ntis',
#  'herf*tbl',
#  'indmom*ep_sp',
#  'realestate*svar',
#  'sic_7',
#  'salerec*dp_sp',
#  'std_dolvol*dfy',
#  'agr*tbl',
#  'mvel1*dp_sp',
#  'invest*svar',
#  'pctacc*ntis',
#  'indmom*svar',
#  'salerec*bm_sp',
#  'std_dolvol*tms',
#  'tang',
#  'maxret*ep_sp',
#  'pchgm_pchsale*dfy',
#  'bm_ia*ep_sp',
#  'maxret*ntis',
#  'cinvest',
#  'rsup*ntis',
#  'rd*ep_sp',
#  'cfp*tms',
#  'mom36m*ep_sp',
#  'mvel1',
#  'pricedelay*tbl',
#  'sic_35',
#  'depr',
#  'pchgm_pchsale*svar',
#  'sin*svar',
#  'chcsho',
#  'sic_55',
#  'cfp_ia*dp_sp',
#  'ear',
#  'chinv*ep_sp',
#  'ep*dfy',
#  'rd_mve*ep_sp',
#  'chpmia*dp_sp',
#  'securedind*ep_sp',
#  'ill*tbl',
#  'securedind*dp_sp',
#  'egr*dp_sp',
#  'cashdebt*dfy',
#  'rd_sale*dp_sp',
#  'chcsho*dp_sp',
#  'invest*bm_sp',
#  'egr*bm_sp',
#  'betasq*svar',
#  'orgcap*bm_sp',
#  'pchgm_pchsale*dp_sp',
#  'quick*dp_sp',
#  'chempia*tms',
#  'rsup*dp_sp',
#  'absacc*tms',
#  'zerotrade*tbl',
#  'std_turn*bm_sp',
#  'pchsaleinv*bm_sp',
#  'divi*dp_sp',
#  'baspread*bm_sp',
#  'herf',
#  'std_turn*tbl',
#  'idiovol*tms',
#  'mom1m*dp_sp',
#  'roaq*dfy',
#  'dolvol*dp_sp',
#  'depr*ntis',
#  'rd_sale*tms',
#  'sic_16',
#  'pchquick*dp_sp',
#  'pchcurrat*tbl',
#  'currat*dp_sp',
#  'pchsale_pchxsga*tms',
#  'sic_34',
#  'pchquick*tms',
#  'cinvest*bm_sp',
#  'acc*ep_sp',
#  'divo*ntis',
#  'std_dolvol*tbl',
#  'grltnoa*bm_sp',
#  'bm_ia*dfy',
#  'pricedelay*ntis',
#  'mom12m*bm_sp',
#  'grltnoa*svar',
#  'mom1m*ntis',
#  'roeq',
#  'sin*tms',
#  'lgr*svar',
#  'std_dolvol',
#  'roavol*bm_sp',
#  'betasq*tms',
#  'mom1m*ep_sp',
#  'quick*ep_sp',
#  'sic_48',
#  'gma*bm_sp',
#  'roic*tms',
#  'orgcap*tbl',
#  'operprof*tbl',
#  'rd_mve*svar',
#  'acc*svar',
#  'cash*dfy',
#  'nincr',
#  'nincr*dfy',
#  'mom12m*dp_sp',
#  'rd_mve*tms',
#  'stdcf*bm_sp',
#  'betasq*tbl',
#  'salecash*dp_sp',
#  'chinv*dp_sp',
#  'tb*svar',
#  'herf*ep_sp',
#  'cashdebt*tms',
#  'secured*tbl',
#  'pchsale_pchxsga*bm_sp',
#  'herf*tms',
#  'ps*dfy',
#  'sic_20',
#  'roeq*ep_sp',
#  'currat*dfy',
#  'roeq*tbl',
#  'convind*tms',
#  'currat*tms',
#  'age',
#  'sic_10',
#  'saleinv*dp_sp',
#  'cash',
#  'cash*svar',
#  'convind*svar',
#  'indmom*dp_sp',
#  'ms*tms',
#  'absacc*svar',
#  'pchsale_pchxsga*dp_sp',
#  'rd_mve*tbl',
#  'currat',
#  'pchcurrat*svar',
#  'tang*ep_sp',
#  'cinvest*svar',
#  'absacc*dp_sp',
#  'roavol*ep_sp',
#  'mvel1*svar',
#  'rd_mve',
#  'pchcurrat*dfy',
#  'sp*tms',
#  'realestate*tms',
#  'cinvest*dp_sp',
#  'pchsale_pchxsga*svar',
#  'turn*tms',
#  'absacc*bm_sp',
#  'baspread*dp_sp',
#  'pchdepr*ep_sp',
#  'stdcf*tms',
#  'grltnoa*tms',
#  'rd*dfy',
#  'cashpr',
#  'securedind',
#  'pchquick*ntis',
#  'sic_29',
#  'roeq*bm_sp',
#  'pchquick*bm_sp',
#  'mom36m*bm_sp',
#  'cfp*ntis',
#  'sic_60',
#  'realestate*ntis',
#  'turn*dfy',
#  'age*dp_sp',
#  'operprof*tms',
#  'idiovol*ep_sp',
#  'pchsale_pchxsga*tbl',
#  'roeq*ntis',
#  'saleinv*tbl',
#  'indmom*tms',
#  'std_dolvol*dp_sp',
#  'divo*svar',
#  'pchsaleinv*ntis',
#  'gma*svar',
#  'depr*ep_sp',
#  'ms*bm_sp',
#  'ps',
#  'cfp_ia*dfy',
#  'chcsho*tbl',
#  'invest*dfy',
#  'ep*dp_sp',
#  'saleinv*ntis',
#  'maxret*dp_sp',
#  'chmom*ep_sp',
#  'sic_14',
#  'pchsaleinv*dp_sp',
#  'chcsho*ep_sp',
#  'pctacc*dp_sp',
#  'chmom*tbl',
#  'secured',
#  'sic_78',
#  'indmom',
#  'sic_44',
#  'sic_63',
#  'salecash*tbl',
#  'mom6m*ep_sp',
#  'std_turn',
#  'sic_52',
#  'mvel1*dfy',
#  'age*ep_sp',
#  'grcapx*dfy',
#  'orgcap*tms',
#  'stdacc',
#  'pchcapx_ia*tbl',
#  'sic_65',
#  'ill*svar',
#  'sic_33',
#  'rd_mve*ntis',
#  'absacc*dfy',
#  'chinv',
#  'mom6m*dp_sp',
#  'sic_82',
#  'chmom*svar',
#  'beta',
#  'dy*bm_sp',
#  'mvel1*tms',
#  'indmom*tbl',
#  'std_dolvol*bm_sp',
#  'sin',
#  'pchsale_pchxsga',
#  'egr*ntis',
#  'nincr*ntis',
#  'rd_sale*bm_sp',
#  'chtx*bm_sp',
#  'pctacc*ep_sp',
#  'pchsale_pchxsga*ntis',
#  'ill*ntis',
#  'cash*bm_sp',
#  'quick*tms',
#  'mom6m*tbl',
#  'roavol',
#  'mom12m*svar',
#  'pchcapx_ia*bm_sp',
#  'sic_59',
#  'divi*tbl',
#  'rd*ntis',
#  'securedind*tbl',
#  'pchsale_pchrect*svar',
#  'std_turn*ntis',
#  'sp',
#  'agr*tms',
#  'rd_sale*ep_sp',
#  'cfp_ia*svar',
#  'bm',
#  'ps*tbl',
#  'sic_99',
#  'hire*ep_sp',
#  'mom12m*dfy',
#  'chtx*ntis',
#  'sin*tbl',
#  'cashpr*ep_sp',
#  'grltnoa*dfy',
#  'pchcapx_ia*dp_sp',
#  'grcapx*tms',
#  'roaq*dp_sp',
#  'cash*tbl',
#  'lgr*tms',
#  'chatoia*ntis',
#  'stdcf*ep_sp',
#  'acc',
#  'mom36m*svar',
#  'ep*tbl',
#  'pricedelay*tms',
#  'invest*ep_sp',
#  'mve_ia*svar',
#  'cfp*dp_sp',
#  'cfp*bm_sp',
#  'pchsale_pchxsga*dfy',
#  'pchgm_pchsale*tbl',
#  'mve_ia*dp_sp',
#  'herf*svar',
#  'sgr*svar',
#  'pctacc*tbl',
#  'lev*tms',
#  'roaq*ntis',
#  'rsup',
#  'tb*tbl',
#  'zerotrade*ep_sp',
#  'age*svar',
#  'cashpr*dp_sp',
#  'ps*tms',
#  'dolvol*svar']

# %%
# get 94 original features missing_info and correlation
flat_corr = pd.read_csv(r"flat_corr.csv", index_col = 0)  # pairs correlation
correlation_df_all = pd.read_csv(r"correlation_df_all.csv", index_col = 0)  # correlation with returns, p-values, and missing_percentage

# %%
flat_corr
# Out:
#             Unnamed: 1         0
# pchquick     pchcurrat  0.974965
# pchcurrat     pchquick  0.974965
# quick           currat  0.971270
# currat           quick  0.971270
# beta            betasq  0.928150
# ...                ...       ...
# agr                lgr -0.603991
# std_dolvol      dolvol -0.650953
# dolvol      std_dolvol -0.650953
# acc             absacc -0.672360
# absacc             acc -0.672360
#
# [8742 rows x 2 columns]

# %%
correlation_df_all
# Out:
#             Correlation        P-Value  missing_per
# Feature
# baspread       3.247846  6.964088e-192     0.002055
# retvol         3.082055  7.123661e-173     0.070231
# rsup          -3.025205  2.455471e-125    25.136322
# maxret         2.610924  1.066366e-124     0.002055
# sp             1.938797   1.605989e-54    22.261562
# ...                 ...            ...          ...
# chatoia       -0.037087   7.757253e-01    28.670843
# ms             0.036791   7.736797e-01    26.150865
# mom12m         0.027462   8.090454e-01     6.393688
# securedind    -0.016067   8.974671e-01    22.246331
# zerotrade     -0.011718   9.151283e-01     0.018736
#
# [94 rows x 3 columns]

# %%
chars = correlation_df_all.index # original 94 features

# %% [markdown]
# ### Define Functions
# - Huber Loss Functions
# - Out-of-sample R-squared
# - Validation Function Using GridSerach Cross-validation
# - Huber Loss Gradients

# %%
from sklearn.model_selection import ParameterGrid

# Huber objective function
def huber_loss(actual, predicted, xi=0.5): 
    residual = actual - predicted
    huber_loss = np.where(np.abs(residual) <= xi, residual**2, 2 * xi * (np.abs(residual) - 0.5 * xi))
    return np.mean(huber_loss)

# Scoring function for out-of-sample R squared
def r2_oos(actual, predicted):
    # Convert input arrays to NumPy arrays
    actual, predicted = np.array(actual), np.array(predicted).flatten()
    
    # Calculate the sum of squared differences between actual and predicted
    ss_residual = np.sum((actual - predicted) ** 2)
    
    # Calculate the total sum of squares (using the mean of actual values as the reference)
    ss_total = np.sum((actual) ** 2)
    
    # Calculate R squared
    r_squared = 1 - (ss_residual / ss_total)
    
    # Return the calculated R squared
    return r_squared

# Validation Function using GridSearchCV
def val_fun_GridSearch(model, params: dict, X_train, y_train, X_val, y_val):
    scorer = make_scorer(huber_loss, greater_is_better=False)
#   grid_search = GridSearchCV(model, params, scoring=scorer, cv=5, verbose=0)
    grid_search = GridSearchCV(model, params, scoring=scorer, verbose=0)
    grid_search.fit(X_train, y_train, eval_set=[X_val, y_val])
    
    best_model = grid_search.best_estimator_
    best_params = grid_search.best_params_

    y_pred = best_model.predict(X_val)
    best_ros = r2_oos(y_val, y_pred)

    print('\n' + '#' * 60)
    print('Tuning process finished!!!')
    print(f'The best setting is: {best_params}')
    print(f'Out-of-sample R-squared on validation set is: {best_ros * 100:.2f}%')
    print('#' * 60)
    
    return best_model


# Validation Function
def val_fun(model, params: dict, X_train, y_train, X_val, y_val):
    best_score=float('inf')
    # Hyperparameter tuning loop
    for params_sample in ParameterGrid(params):
        print(params_sample)
        model = model.set_params(**params_sample)
        model.fit(X_train, y_train)

        # Evaluate on the validation set
        y_val_pred = model.predict(X_val)
        mse_val = huber_loss(y_val, y_val_pred)

        # Check if this set of hyperparameters is the best so far
        if mse_val < best_score:
            best_score = mse_val
            best_params = params_sample

    # Train the final model with the best hyperparameters on the full training set
    best_model = model.set_params(**best_params)
    best_model.fit(X_train, y_train)

    # Evaluate the final model on the validation set
    y_pred = best_model.predict(X_val)
    best_ros = r2_oos(y_val, y_pred)
        
    print('\n' + '#' * 60)
    print('Tuning process finished!!!')
    print(f'The best setting is: {best_params}')
    print(f'Out-of-sample R-squared on validation set is: {best_ros * 100:.2f}%')
    print('#' * 60)

    return best_model   


# best_model = DecisionTreeRegressor()
# best_model.set_params(**best_params)  # set best hyperparameters
# best_model.fit(X_train, y_train)
    

def report_result(model, X_train, y_train, X_test, y_test):
    print('\n' + '#' * 60)
    print(f"In-sample R-squared is: {r2_oos(y_train, model.predict(X_train)) * 100:.2f}%")
    print(f"Out-of-sample R-squared is: {r2_oos(y_test, model.predict(X_test)) * 100:.2f}%")
    print('#' * 60)

# %%
import numpy as np

# Gradient of Huber objective function with respect to predicted values
def grad_huber_obj(actual, predicted, xi):
    residual = actual - predicted
    gradient = np.where(np.abs(residual) <= xi, -2 * residual, -2 * xi * np.sign(residual))
    return gradient / len(actual)

# Hessian of Huber objective function with respect to predicted values
def hess_huber_obj(actual, predicted, xi):
    residual = actual - predicted
    hessian = np.where(np.abs(residual) <= xi, 2, 2 * xi)
    return hessian / len(actual)

# Example usage in a LightGBM objective
def huber_objective(actual, predicted):
    xi = 0.5
    loss = huber_loss(actual, predicted, xi)
    grad = grad_huber_obj(actual, predicted, xi)
    hess = hess_huber_obj(actual, predicted, xi)
    return grad, hess

# %% [markdown]
# ### Datasets

# %%
# # features is the list of feature names
# # 900+ features

# Extract features and target from the datasets
train_dataset_top = train_dataset_top.dropna()
X_train = train_dataset_top[features_top]
y_train = train_dataset_top["RET"]

val_dataset_top = val_dataset_top.dropna()
X_val = val_dataset_top[features_top]
y_val = val_dataset_top["RET"]

test_dataset_top = test_dataset_top.dropna()
X_test = test_dataset_top[features_top]
y_test = test_dataset_top["RET"]

# %%
# Only 94 Features

# # Extract features and target from the datasets
# train_dataset_top = train_dataset_top.dropna().head(8000)
# X_train_94char = train_dataset_top[chars]
# y_train_94char = train_dataset_top["RET"]

# val_dataset_top = val_dataset_top.dropna().head(2000)
# X_val_94char = val_dataset_top[chars]
# y_val_94char = val_dataset_top["RET"]

# test_dataset_top = test_dataset_top.dropna().head(2000)
# X_test_94char = test_dataset_top[chars]
# y_test_94char = test_dataset_top["RET"]

# %%
# Extract features and target from the datasets
train_dataset_top = train_dataset_top.dropna()
X_train_94char = train_dataset_top[chars]
y_train_94char = train_dataset_top["RET"]

val_dataset_top = val_dataset_top.dropna()
X_val_94char = val_dataset_top[chars]
y_val_94char = val_dataset_top["RET"]

test_dataset_top = test_dataset_top.dropna()
X_test_94char = test_dataset_top[chars]
y_test_94char = test_dataset_top["RET"]

# %%
y_train_94char.describe()
# Out:
# count    71837.000000
# mean         0.010329
# std          0.082442
# min         -0.856198
# 25%         -0.035366
# 50%          0.011404
# 75%          0.054845
# max          0.860653
# Name: RET, dtype: float64

# %%
len(features_top)
# Out:
# 911

# %%
X_train_94char
# Out:
#         baspread    retvol      rsup    maxret        sp       sgr    chcsho  \
# 165    -0.775794 -0.763373  0.653197 -0.864516 -0.970232 -0.572842  0.649272
# 167    -0.769566 -0.783376  0.650936 -0.881460 -0.964967 -0.562053 -0.463802
# 176    -0.732621 -0.766019  0.653197 -0.890465 -0.970232 -0.572842  0.649272
# 178    -0.768378 -0.790169  0.653197 -0.903153 -0.970232 -0.572842  0.647289
# 181    -0.840305 -0.881242  0.663487 -0.961677 -0.970232 -0.572842  0.756123
# ...          ...       ...       ...       ...       ...       ...       ...
# 143995 -0.804891 -0.798905  0.647085 -0.878953 -0.951214 -0.625681 -0.428738
# 143996 -0.711113 -0.742429  0.651237 -0.918862 -0.951435 -0.626817 -0.428634
# 143997 -0.697334 -0.723153  0.633342 -0.866890 -0.943758 -0.751365 -0.431318
# 143998 -0.713384 -0.758866  0.652520 -0.913256 -0.935536 -0.674278 -0.436118
# 143999 -0.579556 -0.640022  0.650270 -0.757473 -0.974246 -0.608483 -0.421568
#
#              agr  pchsale_pchxsga  realestate  ...    currat  cashdebt  \
# 165     0.536005        -0.420397   -0.329844  ... -0.980949  0.574771
# 167     0.499835        -0.382289   -0.326746  ... -0.966476  0.603289
# 176     0.536005        -0.420397   -0.322474  ... -0.980949  0.574771
# 178     0.536005        -0.420397   -0.326229  ... -0.980949  0.574771
# 181     0.536005        -0.420397   -0.341188  ... -0.980949  0.574771
# ...          ...              ...         ...  ...       ...       ...
# 143995  0.586644        -0.373019   -0.332407  ... -0.966647  0.515214
# 143996  0.584245        -0.372401   -0.340619  ... -0.966735  0.515583
# 143997  0.619011        -0.432972   -0.301236  ... -0.924003  0.517513
# 143998  0.686721        -0.416632   -0.501394  ... -0.823766  0.601373
# 143999  0.483573        -0.311333   -0.278658  ... -0.864381  0.683962
#
#             beta      roaq  salecash   chatoia    ms    mom12m  securedind  \
# 165    -0.392488  0.475231 -0.984674 -0.009970  0.75 -0.687399        -1.0
# 167    -0.373529  0.473642 -0.990925 -0.134365  0.75 -0.641790        -1.0
# 176    -0.359465  0.475231 -0.984674 -0.009970  0.75 -0.610022        -1.0
# 178    -0.351181  0.475231 -0.984674 -0.009970  0.75 -0.661673        -1.0
# 181    -0.377502  0.619684 -0.984674 -0.009970  0.75 -0.681327        -1.0
# ...          ...       ...       ...       ...   ...       ...         ...
# 143995 -0.417357  0.381743 -0.987154  0.065825  0.25 -0.738228        -1.0
# 143996 -0.354021  0.382525 -0.987602  0.065415  0.25 -0.743478        -1.0
# 143997 -0.217733  0.387326 -0.990437 -0.291321  0.50 -0.728523         1.0
# 143998 -0.569619  0.411327 -0.994328 -0.090422 -0.25 -0.731210        -1.0
# 143999 -0.156725  0.468074 -0.993943  0.198425  0.50 -0.732082         1.0
#
#         zerotrade
# 165          -1.0
# 167          -1.0
# 176          -1.0
# 178          -1.0
# 181          -1.0
# ...           ...
# 143995       -1.0
# 143996       -1.0
# 143997       -1.0
# 143998       -1.0
# 143999       -1.0
#
# [71837 rows x 94 columns]

# %% [markdown]
# ## Decision Trees

# %% [markdown]
# ### Decision Tree with 900+ Features

# %%
# %%time

from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error


params = {
    'max_depth':[3,5,10,20],
    'min_samples_split': [2],
    'min_samples_leaf': [1],
    'random_state':[42]
}


DecisionTree_all = val_fun(DecisionTreeRegressor(), params=params, X_train=X_train, y_train=y_train, X_val=X_val, y_val=y_val)
# Out:
# {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 42}
# {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 42}
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 42}
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 42}
#
# ############################################################
# Tuning process finished!!!
# The best setting is: {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 42}
# Out-of-sample R-squared on validation set is: -54.84%
# ############################################################
# CPU times: total: 3min 42s
# Wall time: 5min 54s

# %%
DecisionTree_all
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=42)

# %%
report_result(model=DecisionTree_all, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
# Out:
# ############################################################
# In-sample R-squared is: 12.93%
# Out-of-sample R-squared is: 2.05%
# ############################################################

# %%
# Save the model to a file
joblib.dump(DecisionTree_all, 'model_details/DecisionTree_all_top.joblib')

# # Load the model from the file
# loaded_model = joblib.load('random_forest_model.joblib')
# Out:
# ['model_details/DecisionTree_all_top.joblib']

# %% [markdown]
# ### Decision Tree with 94 Features

# %%
# %%time

from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error


params = {
    'max_depth':[3,5,10,20],
    'min_samples_split': [2],
    'min_samples_leaf': [1],
    'random_state':[42]
}


DecisionTree = val_fun(DecisionTreeRegressor(), params=params, X_train=X_train_94char, y_train=y_train_94char, X_val=X_val_94char, y_val=y_val_94char)
# Out:
# {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 42}
# {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 42}
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 42}
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 42}
#
# ############################################################
# Tuning process finished!!!
# The best setting is: {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'random_state': 42}
# Out-of-sample R-squared on validation set is: 0.71%
# ############################################################
# CPU times: total: 16.7 s
# Wall time: 30.7 s

# %%
DecisionTree
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=42)

# %%
report_result(model=DecisionTree, X_train=X_train_94char, y_train=y_train_94char, X_test=X_test_94char, y_test=y_test_94char)
# Out:
# ############################################################
# In-sample R-squared is: 4.78%
# Out-of-sample R-squared is: -1.99%
# ############################################################

# %%
# Save the model to a file
joblib.dump(DecisionTree, 'model_details/DecisionTree_top.joblib')
# Out:
# ['model_details/DecisionTree_top.joblib']

# %% [markdown]
# ### Random Forest

# %% [markdown]
# ### Random Forest with 900+ Features

# %%
# %%time
from sklearn.ensemble import RandomForestRegressor

params = {
    'n_estimators': [300],
    'max_depth': [3, 6],
    'max_features': [30, 50, 100],
    'random_state': [42]
}

# params = {
#     'n_estimators': [300],
#     'max_depth': [3, 6],
#     'max_features': [30],
#     'random_state': [42]
# }

RamdonForest_all = val_fun(RandomForestRegressor(), params=params, X_train=X_train, y_train=y_train, X_val=X_val, y_val=y_val)
# Out:
# {'max_depth': 3, 'max_features': 30, 'n_estimators': 300, 'random_state': 42}
# {'max_depth': 3, 'max_features': 50, 'n_estimators': 300, 'random_state': 42}
# {'max_depth': 3, 'max_features': 100, 'n_estimators': 300, 'random_state': 42}
# {'max_depth': 6, 'max_features': 30, 'n_estimators': 300, 'random_state': 42}
# {'max_depth': 6, 'max_features': 50, 'n_estimators': 300, 'random_state': 42}
# {'max_depth': 6, 'max_features': 100, 'n_estimators': 300, 'random_state': 42}
#
# ############################################################
# Tuning process finished!!!
# The best setting is: {'max_depth': 6, 'max_features': 30, 'n_estimators': 300, 'random_state': 42}
# Out-of-sample R-squared on validation set is: 1.38%
# ############################################################
# CPU times: total: 48min 50s
# Wall time: 1h 11min 32s

# %%
RamdonForest_all
# Out:
# RandomForestRegressor(max_depth=6, max_features=30, n_estimators=300,
#                       random_state=42)

# %%
report_result(model=RamdonForest_all, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
# Out:
# ############################################################
# In-sample R-squared is: 20.53%
# Out-of-sample R-squared is: 3.29%
# ############################################################

# %%
# Save the model to a file
joblib.dump(RamdonForest_all, 'model_details/RamdonForest_all_top.joblib')
# Out:
# ['model_details/RamdonForest_all_top.joblib']

# %% [markdown]
# ### Random Forest with 96 Features

# %%
# %%time
from sklearn.ensemble import RandomForestRegressor

params = {
    'n_estimators': [300],
    'max_depth': [3, 6],
    'max_features': [30, 50, 100],
    'random_state': [42]
}

# params = {
#     'n_estimators': [300],
#     'max_depth': [3, 6],
#     'max_features': [30],
#     'random_state': [42]
# }

RamdonForest = val_fun(RandomForestRegressor(), params=params, X_train=X_train_94char, y_train=y_train_94char, X_val=X_val_94char, y_val=y_val_94char)
# Out:
# {'max_depth': 3, 'max_features': 30, 'n_estimators': 300, 'random_state': 42}
# {'max_depth': 3, 'max_features': 50, 'n_estimators': 300, 'random_state': 42}
# {'max_depth': 3, 'max_features': 100, 'n_estimators': 300, 'random_state': 42}
# {'max_depth': 6, 'max_features': 30, 'n_estimators': 300, 'random_state': 42}
# {'max_depth': 6, 'max_features': 50, 'n_estimators': 300, 'random_state': 42}
# {'max_depth': 6, 'max_features': 100, 'n_estimators': 300, 'random_state': 42}
#
# ############################################################
# Tuning process finished!!!
# The best setting is: {'max_depth': 3, 'max_features': 30, 'n_estimators': 300, 'random_state': 42}
# Out-of-sample R-squared on validation set is: 1.91%
# ############################################################
# CPU times: total: 33min 12s
# Wall time: 42min 38s

# %%
RamdonForest
# Out:
# RandomForestRegressor(max_depth=3, max_features=30, n_estimators=300,
#                       random_state=42)

# %%
report_result(model=RamdonForest, X_train=X_train_94char, y_train=y_train_94char, X_test=X_test_94char, y_test=y_test_94char)
# Out:
# ############################################################
# In-sample R-squared is: 4.87%
# Out-of-sample R-squared is: -0.57%
# ############################################################

# %%
# Save the model to a file
joblib.dump(RamdonForest, 'model_details/RamdonForest_top.joblib')
# Out:
# ['model_details/RamdonForest_top.joblib']

# %% [markdown]
# ### LightGBM

# %%
# !pip install lightgbm

# %%
# %%time
import numpy as np

# Gradient of Huber objective function with respect to predicted values
def grad_huber_obj(actual, predicted, xi):
    residual = actual - predicted
    gradient = np.where(np.abs(residual) <= xi, -2 * residual, -2 * xi * np.sign(residual))
    return gradient / len(actual)

# Hessian of Huber objective function with respect to predicted values
def hess_huber_obj(actual, predicted, xi):
    residual = actual - predicted
    hessian = np.where(np.abs(residual) <= xi, 2, 2 * xi)
    return hessian / len(actual)

# Example usage in a LightGBM objective
def huber_objective(actual, predicted):
    xi = 0.5
    loss = huber_loss(actual, predicted, xi)
    grad = grad_huber_obj(actual, predicted, xi)
    hess = hess_huber_obj(actual, predicted, xi)
    return grad, hess
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %% [markdown]
# ### LightGBM with 900+ Features

# %%
# %%time
import lightgbm as lgb
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

params = {
    'objective':[None, huber_objective],
    'max_depth':[1,2,3,5,10],
    'num_leaves': [10,30,50,80],
    'n_estimators':[10,50,100,500],
    'random_state':[42],
    'learning_rate':[0.01,.1]
}


# params = {
#     'objective':[None,huber_objective],
#     'max_depth':[1,2,5,10,20],
#     'n_estimators':[10,50,100,200,500,1000],
#     'random_state':[42],
#     'learning_rate':[.01,.1]
# }
    
    
# # Define hyperparameters
# params = {
#     'objective': 'regression',  # Note: The objective here is set to 'regression'
#     'metric': 'mse',
#     'boosting_type': 'gbdt',
#     'num_leaves': 31,
#     'learning_rate': 0.05,
#     'feature_fraction': 0.9
# }


LGBM_all = val_fun(lgb.LGBMRegressor(), params=params, X_train=X_train, y_train=y_train, X_val=X_val, y_val=y_val)
# Out:
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.356465 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.325187 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.355967 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.381922 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.419684 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.490124 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.480059 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.511105 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.480145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.480273 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.488209 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.495765 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.511811 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.484885 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.481567 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.494486 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.483091 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.473818 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.494574 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.462554 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.487239 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.505381 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.476016 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.470193 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.450896 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.517233 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.488182 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.510366 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.469216 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.472816 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.506991 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.488932 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.464999 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.525634 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.503955 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.422473 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.437974 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.457289 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.436640 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.427835 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.451067 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.431391 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.412750 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.421795 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.430030 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.451451 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.453644 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.411952 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.450231 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.417253 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.432594 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.432021 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.421397 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.434059 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.423031 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.448883 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.423957 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.452051 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.416285 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.421526 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.428539 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.439294 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.457131 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.405659 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.431812 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.448647 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.429283 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.421766 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.411353 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.426406 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.448267 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.429656 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.414001 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.444565 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.416927 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.429731 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.411380 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.416358 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.391095 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.443883 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.433614 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.442596 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.440548 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.411656 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.421122 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.427921 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.425328 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.428136 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.426103 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.452864 seconds.
# ...
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.496895 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.445169 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.504790 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.464750 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.492894 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.418378 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.540727 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.535595 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.460498 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.492640 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.445208 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.551907 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.495281 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.530482 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.511531 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.562584 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.511760 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.491013 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.476192 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.425716 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
#
# ############################################################
# Tuning process finished!!!
# The best setting is: {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# Out-of-sample R-squared on validation set is: 2.80%
# ############################################################
# CPU times: total: 10h 9min 58s
# Wall time: 10h 51min 17s

# %%
LGBM_all
# Out:
# LGBMRegressor(learning_rate=0.01, max_depth=1, n_estimators=10, num_leaves=10,
#               random_state=42)

# %%
report_result(model=LGBM_all, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
# Out:
# ############################################################
# In-sample R-squared is: 2.17%
# Out-of-sample R-squared is: 1.45%
# ############################################################

# %%
# Save the model to a file
joblib.dump(LGBM_all, 'model_details/LGBM_all_top.joblib')
# Out:
# ['model_details/LGBM_all_top.joblib']

# %%
# %%time

params = {
    'objective':[None, huber_objective],
    'max_depth':[1,2],
    'n_estimators':[10,50,100,200,500,1000],
    'random_state':[42],
    'learning_rate':[.01,.1]
}

LGBM_all_2 = val_fun(lgb.LGBMRegressor(), params=params, X_train=X_train, y_train=y_train, X_val=X_val, y_val=y_val)
# Out:
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.396311 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.409304 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.395413 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.390255 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.386287 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.416386 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 200, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.417681 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 200, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.490457 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.533637 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.472910 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 1000, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.487892 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 1000, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.507874 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.426226 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.474364 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.504111 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.416837 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.384711 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.505452 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 200, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.497849 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 200, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.528963 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.448247 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.501158 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 1000, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.517723 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 1000, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.490443 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.420407 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.527617 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.478340 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.506484 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 100, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.408073 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 100, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.509942 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 200, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.445659 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 200, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.458419 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 500, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.552503 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 500, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.506146 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 1000, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.452812 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 1000, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.390475 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.407920 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.412324 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.438489 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.561949 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.423537 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.512775 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 200, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.530483 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 200, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.523635 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 500, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.563911 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 500, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.464771 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 1000, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.550463 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 1000, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.539636 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.545458 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 203755
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 909
# [LightGBM] [Info] Start training from score 0.010329
#
# ############################################################
# Tuning process finished!!!
# The best setting is: {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'objective': None, 'random_state': 42}
# Out-of-sample R-squared on validation set is: 2.80%
# ############################################################
# CPU times: total: 1h 26min 40s
# Wall time: 17min 19s

# %%
LGBM_all_2
# Out:
# LGBMRegressor(learning_rate=0.01, max_depth=1, n_estimators=10, random_state=42)

# %%
report_result(model=LGBM_all_2, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
# Out:
# ############################################################
# In-sample R-squared is: 2.17%
# Out-of-sample R-squared is: 1.45%
# ############################################################

# %%
# Save the model to a file
joblib.dump(LGBM_all_2, 'model_details/LGBM_all_2_top.joblib')
# Out:
# ['model_details/LGBM_all_2_top.joblib']

# %% [markdown]
# ### LightGBM with 94 Feaures

# %%
# %%time
import lightgbm as lgb
import numpy as np
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

params = {
    'objective':[None, huber_objective],
    'max_depth':[1,2,3,5,10],
    'num_leaves': [10,30,50,80],
    'n_estimators':[10,50,100,500],
    'random_state':[42],
    'learning_rate':[0.01,.1]
}


# params = {
#     'objective':[None, huber_objective],
#     'max_depth':[1,2,5,10],
#     'n_estimators':[10,50,100,200,500,1000],
#     'random_state':[42],
#     'learning_rate':[.01,.1]
# }


# params = {
#     'objective':[None, huber_objective],
#     'max_depth':[1,2,5,10],
#     'num_leaves': [10,30],
#     'n_estimators':[10,50],
#     'random_state':[42],
#     'learning_rate':[.1]
# }

# # Define hyperparameters
# params = {
#     'objective': 'regression',  # Note: The objective here is set to 'regression'
#     'metric': 'mse',
#     'boosting_type': 'gbdt',
#     'num_leaves': 31,
#     'learning_rate': 0.05,
#     'feature_fraction': 0.9
# }

# LGBM = val_fun_GridSearch(lgb.LGBMRegressor(), params=params, X_train=X_train_94char, y_train=y_train_94char, X_val=X_val_94char, y_val=y_val_94char)
LGBM = val_fun(lgb.LGBMRegressor(), params=params, X_train=X_train_94char, y_train=y_train_94char, X_val=X_val_94char, y_val=y_val_94char)
# Out:
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040730 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038987 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038939 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037536 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038290 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034092 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034016 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034811 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039789 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.041094 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037392 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037899 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036420 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032654 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033103 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 50, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037722 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039267 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038026 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036215 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036350 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033832 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039893 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036713 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 100, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037103 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037844 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035862 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037489 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038288 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033499 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036494 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038220 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 500, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035081 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034690 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037061 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022795 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037612 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038380 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032504 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036521 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 10, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037719 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035828 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035734 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038162 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038478 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037147 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033897 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.042812 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038643 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036675 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038254 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032992 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040334 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036315 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036365 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037751 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 100, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037871 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037222 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033981 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034340 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032801 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036339 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037065 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034510 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 500, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035040 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034728 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033634 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034667 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035847 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035313 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034705 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034482 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034594 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035560 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039428 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.033644 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034952 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037939 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039351 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037862 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 50, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039706 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037748 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034242 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034417 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036080 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038430 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039144 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034584 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.041648 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.042532 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034610 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 10, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037782 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 10, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035292 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 10, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040185 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 10, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040557 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035538 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035670 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036326 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039728 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037808 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035641 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037019 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037959 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037878 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036498 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034506 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.037210 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036405 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040830 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.038527 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034369 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 10, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.032764 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 10, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039450 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047273 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 30, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.039147 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 50, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035382 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036282 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 80, 'objective': None, 'random_state': 42}
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.040753 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
# {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500, 'num_leaves': 80, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'random_state': 42}
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.035334 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Using self-defined objective function
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.036554 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21523
# [LightGBM] [Info] Number of data points in the train set: 71837, number of used features: 94
# [LightGBM] [Info] Start training from score 0.010329
#
# ############################################################
# Tuning process finished!!!
# The best setting is: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 10, 'num_leaves': 30, 'objective': None, 'random_state': 42}
# Out-of-sample R-squared on validation set is: 2.95%
# ############################################################
# CPU times: total: 1h 49min 46s
# Wall time: 15min 50s

# %%
LGBM
# Out:
# LGBMRegressor(learning_rate=0.01, max_depth=10, n_estimators=10, num_leaves=30,
#               random_state=42)

# %%
report_result(model=LGBM, X_train=X_train_94char, y_train=y_train_94char, X_test=X_test_94char, y_test=y_test_94char)
# Out:
# ############################################################
# In-sample R-squared is: 3.06%
# Out-of-sample R-squared is: 1.42%
# ############################################################

# %%
# Save the model to a file
joblib.dump(LGBM, 'model_details/LGBM_top.joblib')
# Out:
# ['model_details/LGBM_top.joblib']

# %% [markdown]
# ## XGBoost

# %%
# !pip install xgboost

# %% [markdown]
# ### XGBoost with 900+ Features

# %%
# %%time
import xgboost as xgb
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV
import numpy as np

params = {
    'objective': [None, huber_objective],  # Using Huber loss for regression
    'max_depth': [2,3,5,10],  # Adjust the maximum depth of the trees
    'learning_rate': [0.1],
    'subsample': [0.8],
    'colsample_bytree': [0.8],
    'n_estimators': [50, 100, 200]  # Number of boosting rounds
}

# XGBoost = val_fun_GridSearch(xgb.XGBRegressor(), params=params, X_train=X_train_94char, y_train=y_train_94char, X_val=X_val_94char, y_val=y_val_94char)
XGBoost_all = val_fun(xgb.XGBRegressor(), params=params, X_train=X_train, y_train=y_train, X_val=X_val, y_val=y_val)
# Out:
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 200, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 200, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 200, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 200, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
#
# ############################################################
# Tuning process finished!!!
# The best setting is: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# Out-of-sample R-squared on validation set is: 2.94%
# ############################################################
# CPU times: total: 1h 56min 12s
# Wall time: 16min 6s

# %%
XGBoost_all
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=2, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None,
#              objective=<function huber_objective at 0x00000212A2DCC700>, ...)

# %%
report_result(model=XGBoost_all, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
# Out:
# ############################################################
# In-sample R-squared is: 1.54%
# Out-of-sample R-squared is: 1.28%
# ############################################################

# %%
# Save the model to a file
joblib.dump(XGBoost_all, 'model_details/XGBoost_all_top.joblib')
# Out:
# ['model_details/XGBoost_all_top.joblib']

# %% [markdown]
# ### XGBoost with 94 Features

# %%
# %%time
import xgboost as xgb
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV
import numpy as np

params = {
    'objective': [None, huber_objective],  # Using Huber loss for regression
    'max_depth': [2,3,5,10],  # Adjust the maximum depth of the trees
    'learning_rate': [0.1],
    'subsample': [0.8],
    'colsample_bytree': [0.8],
    'n_estimators': [50, 100, 200]  # Number of boosting rounds
}

# XGBoost = val_fun_GridSearch(xgb.XGBRegressor(), params=params, X_train=X_train_94char, y_train=y_train_94char, X_val=X_val_94char, y_val=y_val_94char)
XGBoost = val_fun(xgb.XGBRegressor(), params=params, X_train=X_train_94char, y_train=y_train_94char, X_val=X_val_94char, y_val=y_val_94char)
# Out:
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 200, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 200, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 50, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 200, 'objective': None, 'subsample': 0.8}
# {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 200, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
#
# ############################################################
# Tuning process finished!!!
# The best setting is: {'colsample_bytree': 0.8, 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 100, 'objective': <function huber_objective at 0x00000212A2DCC700>, 'subsample': 0.8}
# Out-of-sample R-squared on validation set is: 2.94%
# ############################################################
# CPU times: total: 20min 58s
# Wall time: 2min 52s

# %%
XGBoost
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=2, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None,
#              objective=<function huber_objective at 0x00000212A2DCC700>, ...)

# %%
report_result(model=XGBoost, X_train=X_train_94char, y_train=y_train_94char, X_test=X_test_94char, y_test=y_test_94char)
# Out:
# ############################################################
# In-sample R-squared is: 1.54%
# Out-of-sample R-squared is: 1.28%
# ############################################################

# %%
# Save the model to a file
joblib.dump(XGBoost, 'model_details/XGBoost_top.joblib')
# Out:
# ['model_details/XGBoost_top.joblib']
